# %% [markdown]
# <a href="https://colab.research.google.com/github/anuhyaala/AlaAnuhya/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 12:01:51--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   132MB/s    in 0.5s
#
# 2024-03-31 12:01:51 (132 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3187    1206.6429v1  Matching one set of objects to another is a ub...    cs
# 4387   1703.02184v2  A multiple classifiers fusion localization tec...  stat
# 8554   1704.06036v1  The Correlation Filter is an algorithm that tr...    cs
# 6519   1703.00284v2  For their ability to capture non-linearities i...  stat
# 4176   1701.07396v1  A semi-automatic open-source tool for layout a...    cs
# ...             ...                                                ...   ...
# 1338    1412.7259v3  In this paper, we investigate the problem of l...    cs
# 10125  1707.03377v2  We introduce the Deep Symbolic Network (DSN) m...    cs
# 5997    1402.5836v3  Choosing appropriate architectures and regular...  stat
# 12193  1710.04325v1  We study the construction of coresets for kern...    cs
# 14865   1210.5517v1  Developing parallel corpora is an important an...    cs
#
#                                                    title  year  \
# 3187   Incorporating Domain Knowledge in Matching Pro...  2012
# 4387   Indoor Localization Using Visible Light Via Fu...  2017
# 8554   End-to-end representation learning for Correla...  2017
# 6519   L$^3$-SVMs: Landmarks-based Linear Local Suppo...  2017
# 4176   LAREX - A semi-automatic open-source Tool for ...  2017
# ...                                                  ...   ...
# 1338        Unsupervised Feature Learning with C-SVDDNet  2014
# 10125   Learning like humans with Deep Symbolic Networks  2017
# 5997          Avoiding pathologies in very deep networks  2014
# 12193     Improved Coresets for Kernel Density Estimates  2017
# 14865  Design of English-Hindi Translation Memory for...  2012
#
#                                                 keywords
# 3187   [ubiquitous, quadratic, assignment, notoriousl...
# 4387   [classifiers, localization, technique, strengt...
# 8554   [correlation, algorithm, discriminate, transla...
# 6519   [linearities, attention, introduce, dimensiona...
# 4176   [automatic, presented, connected, components, ...
# ...                                                  ...
# 1338   [investigate, representation, unlabeled, repre...
# 10125  [introduce, universal, structure, represent, k...
# 5997   [appropriate, architectures, regularization, s...
# 12193  [construction, estimates, approximate, describ...
# 14865  [developing, important, difficult, translation...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3187     [ubiquitous, quadratic, assignment, notoriousl...
# 4387     [classifiers, localization, technique, strengt...
# 8554     [correlation, algorithm, discriminate, transla...
# 6519     [linearities, attention, introduce, dimensiona...
# 4176     [automatic, presented, connected, components, ...
#                                ...
# 5771     [performance, shortcoming, unbounded, unsuitab...
# 33081    [performance, classifiers, underlying, multimo...
# 3571     [classifiers, susceptible, adversarial, gradie...
# 10981    [crowdsourcing, effective, computation, challe...
# 22109    [processes, probabilistic, modelling, supervis...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8883 words.
# Out of those 4521 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7e6ffae3-b90a-4549-989e-93020fd2103a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e6ffae3-b90a-4549-989e-93020fd2103a")) {                    Plotly.newPlot(                        "7e6ffae3-b90a-4549-989e-93020fd2103a",                        [{"x":["notoriously","experiments","practical","optimizing","objective","information","investigate","assignment","available","mitigated","parameters","accelerate","functions","difficulty","structure","instances","ubiquitous","quadratic","approaches","application","outperform","symmetric","conjunction","algebraic","permutations","advantage","incorporating","knowledge","additional","conducted","technique","probability","estimators","detection","effectiveness","strengths","dependent","intensity","fingerprints","stability","different","representative","decomposition","experimental","localization","classical","modulated","robustness","sinusoidal","respectively","classifiers","prediction","performance","positioning","demonstrated","algorithms","independent","numerical","capturing","discriminate","important","limitation","formulation","illustrate","correlation","algorithm","translations","differentiable","lightweight","interpreting","architectures","representation","linearities","competitive","projecting","configuration","guarantees","theoretically","reduction","attention","dimensionality","framework","effective","introduce","projection","landmarks","combination","generalization","presented","extraction","necessary","integration","efficient","comprehensible","correction","evaluations","connected","automatic","intuitive","components","workflows","arbitrary","remaining","completion","constraints","processes","agreement","undesirable","situations","forecasts","influence","associated","recurrent","predicting","mechanism","corresponding","sensitivity","estimation","assumptions","observing","cognitive","consuming","treatment","constructs","premature","distribution","estimating","interventional","marginalized","particular","nonparametric","observational","transform","hierarchical","demonstrate","sometimes","interventions","confounders","expensive","controlled","composition","nonparametrically","classification","regression","regularized","introduced","increased","expectations","proportional","necessarily","generated","evaluation","conditions","uncertain","inference","reasoning","restricted","solutions","consistent","deteriorates","identified","generally","prospector","calculations","surprisingly","classifier","supporting","measurement","compressive","diversity","hyperspectral","compressed","isolating","processing","suitability","reconstruct","correspondence","consecutive","conventional","computing","navigation","substantial","extracted","complexity","developed","environment","autonomous","considerable","essential","operational","computational","estimated","keypoints","laboratory","correspond","simplifying","axiomatic","uncertainty","naturally","replacing"],"y":[7,649,123,57,175,668,153,24,296,4,211,25,226,41,357,108,21,29,440,265,78,23,15,17,3,92,59,376,104,77,222,162,14,340,213,16,64,28,4,42,748,36,68,347,65,101,4,95,2,96,100,208,901,6,93,580,117,94,38,7,347,26,77,69,79,816,18,21,14,12,132,377,2,123,9,31,67,36,92,168,47,535,243,327,51,11,131,116,178,132,80,47,423,5,30,51,84,199,38,122,6,86,20,30,138,100,25,11,57,8,47,107,154,66,119,130,33,220,71,21,51,30,33,17,4,194,59,3,3,261,23,4,76,102,546,16,8,1,54,35,37,0,479,110,34,108,37,6,10,22,172,269,126,25,205,115,58,158,79,3,48,70,2,7,27,126,27,28,12,41,16,21,2,271,3,30,32,16,110,128,30,42,113,248,207,121,54,36,81,15,301,67,12,11,37,9,6,75,55,9],"type":"bar"},{"x":["notoriously","experiments","practical","optimizing","objective","information", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4521,), (4521, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>DeepStance</span> <span style=''>at</span> <span style=''>SemEval</span> <span style=''>2016</span> <span style=''>Task</span> <span style=''>6</span> <span style='background-color:rgba(0, 255, 0, 0.3663366336633663);'>Detecting</span> <span style=''>Stance</span> <span style=''>in</span> <span style=''>Tweets</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.6338028169014085);'>Character</span> <span style=''>and</span> <span style=''>Word</span> <span style=''>Level</span> <span style=''>CNNs</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.5945945945945946);'>describes</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3663366336633663);'>Detecting</span> <span style=''>Stance</span> <span style=''>in</span> <span style=''>Tweets</span> <span style=''>task</span> <span style=''>(SemEval</span> <span style=''>2016</span> <span style=''>Task</span> <span style=''>6)</span> <span style=''>We</span> <span style=''>utilized</span> <span style=''>recent</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>short</span> <span style=''>text</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>categorization</span> <span style=''>using</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>create</span> <span style=''>word</span> <span style=''>level</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6338028169014085);'>character</span> <span style=''>level</span> <span style=''>models</span> <span style=''>The</span> <span style=''>choice</span> <span style=''>between</span> <span style=''>word</span> <span style=''>level</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6338028169014085);'>character</span> <span style=''>level</span> <span style=''>models</span> <span style=''>in</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>case</span> <span style=''>was</span> <span style=''>informed</span> <span style=''>through</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>Our</span> <span style=''>final</span> <span style=''>system</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>using</span> <span style=''>word</span> <span style=''>level</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.6338028169014085);'>character</span> <span style=''>level</span> <span style=''>models</span> <span style=''>We</span> <span style=''>also</span> <span style=''>employed</span> <span style=''>novel</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>augmentation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>to</span> <span style=''>expand</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>diversify</span> <span style=''>our</span> <span style=''>training</span> <span style=''>dataset</span> <span style=''>thus</span> <span style=''>making</span> <span style=''>our</span> <span style=''>system</span> <span style=''>more</span> <span style=''>robust</span> <span style=''>Our</span> <span style=''>system</span> <span style=''>achieved</span> <span style=''>a</span> <span style=''>macro</span> <span style=''>average</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precision</span> <span style=''>recall</span> <span style=''>and</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Measuring</span> <span style=''>Sample</span> <span style=''>Quality</span> <span style=''>with</span> <span style=''>Diffusions</span> <br/><br/><span style=''>Steins</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measuring</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>an</span> <span style=''>operator</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterizing</span> <span style=''>the</span> <span style=''>target</span> <span style=''>and</span> <span style=''>Stein</span> <span style=''>factor</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differential</span> <span style=''>equation</span> <span style=''>While</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operators</span> <span style=''>and</span> <span style=''>bounds</span> <span style=''>are</span> <span style=''>readily</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diversity</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>univariate</span> <span style=''>targets</span> <span style=''>few</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>targets</span> <span style=''>have</span> <span style=''>been</span> <span style=''>analyzed</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operators</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Ito</span> <span style=''>diffusions</span> <span style=''>and</span> <span style=''>develop</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>Stein</span> <span style=''>factor</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>any</span> <span style=''>target</span> <span style=''>with</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>coupling</span> <span style=''>Ito</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style=''>As</span> <span style=''>example</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>we</span> <span style=''>develop</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computable</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style=''>Stein</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discrepancies</span> <span style=''>for</span> <span style=''>log</span> <span style=''>concave</span> <span style=''>heavy</span> <span style=''>tailed</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multimodal</span> <span style=''>targets</span> <span style=''>and</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.39837398373983746);'>factorization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>for</span> <span style=''>acyclic</span> <span style=''>directed</span> <span style=''>mixed</span> <span style=''>graphs</span> <br/><br/><span style=''>Acyclic</span> <span style=''>directed</span> <span style=''>mixed</span> <span style=''>graphs</span> <span style=''>also</span> <span style=''>known</span> <span style=''>as</span> <span style=''>semi</span> <span style=''>Markov</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.38378378378378386);'>represent</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.46341463414634154);'>independence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>induced</span> <span style=''>on</span> <span style=''>an</span> <span style=''>observed</span> <span style=''>margin</span> <span style=''>by</span> <span style=''>a</span> <span style=''>DAG</span> <span style=''>model</span> <span style=''>with</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3691588785046728);'>variables</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.39837398373983746);'>factorization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>for</span> <span style=''>these</span> <span style=''>models</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>the</span> <span style=''>global</span> <span style=''>Markov</span> <span style=''>property</span> <span style=''>given</span> <span style=''>by</span> <span style=''>(the</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of)</span> <span style=''>d</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separation</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>for</span> <span style=''>Machine</span> <span style=''>Learning</span> <br/><br/><span style=''>A</span> <span style=''>vast</span> <span style=''>majority</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>train</span> <span style=''>their</span> <span style=''>models</span> <span style=''>and</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>by</span> <span style=''>solving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>problems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accurately</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>such</span> <span style=''>as</span> <span style=''>sparsity</span> <span style=''>or</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequently</span> <span style=''>imposed</span> <span style=''>or</span> <span style=''>else</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>itself</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>function</span> <span style=''>This</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>true</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>operate</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>spaces</span> <span style=''>or</span> <span style=''>that</span> <span style=''>train</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style=''>tensor</span> <span style=''>models</span> <span style=''>and</span> <span style=''>deep</span> <span style=''>networks</span> <span style=''>The</span> <span style=''>freedom</span> <span style=''>to</span> <span style=''>express</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>a</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>gives</span> <span style=''>immense</span> <span style=''>modeling</span> <span style=''>power</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>designer</span> <span style=''>but</span> <span style=''>often</span> <span style=''>such</span> <span style=''>problems</span> <span style=''>are</span> <span style=''>NP</span> <span style=''>hard</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>A</span> <span style=''>popular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>workaround</span> <span style=''>to</span> <span style=''>this</span> <span style=''>has</span> <span style=''>been</span> <span style=''>to ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09552556818181818)
# 	processing (0.09623579545454546)
# 	architecture (0.08345170454545454)
# 	information (0.2372159090909091)
# 	segmentation (0.07528409090909091)
# 	knowledge (0.13352272727272727)
# 	detection (0.12073863636363637)
# 	different (0.265625)
# 	recognition (0.13068181818181818)
# 	convolutional (0.1455965909090909)
#
# Some Statistics words are:
# 	stochastic (0.1350806451612903)
# 	estimation (0.17590725806451613)
# 	variables (0.14768145161290322)
# 	statistical (0.15725806451612903)
# 	algorithm (0.3941532258064516)
# 	theoretical (0.1587701612903226)
# 	distribution (0.1849798387096774)
# 	inference (0.19153225806451613)
# 	regression (0.16683467741935484)
# 	dimensional (0.1970766129032258)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4230037f-a791-4ad3-a9f1-0c9bef5bbd10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4230037f-a791-4ad3-a9f1-0c9bef5bbd10")) {                    Plotly.newPlot(                        "4230037f-a791-4ad3-a9f1-0c9bef5bbd10",                        [{"x":["notoriously","experiments","practical","optimizing","objective","information","investigate","assignment","available","mitigated","parameters","accelerate","functions","difficulty","structure","instances","ubiquitous","quadratic","approaches","application","outperform","symmetric","conjunction","algebraic","permutations","advantage","incorporating","knowledge","additional","conducted","technique","probability","estimators","detection","effectiveness","strengths","dependent","intensity","fingerprints","stability","different","representative","decomposition","experimental","localization","classical","modulated","robustness","sinusoidal","respectively","classifiers","prediction","performance","positioning","demonstrated","algorithms","independent","numerical","capturing","discriminate","important","limitation","formulation","illustrate","correlation","algorithm","translations","differentiable","lightweight","interpreting","architectures","representation","linearities","competitive","projecting","configuration","guarantees","theoretically","reduction","attention","dimensionality","framework","effective","introduce","projection","landmarks","combination","generalization","presented","extraction","necessary","integration","efficient","comprehensible","correction","evaluations","connected","automatic","intuitive","components","workflows","arbitrary","remaining","completion","constraints","processes","agreement","undesirable","situations","forecasts","influence","associated","recurrent","predicting","mechanism","corresponding","sensitivity","estimation","assumptions","observing","cognitive","consuming","treatment","constructs","premature","distribution","estimating","interventional","marginalized","particular","nonparametric","observational","transform","hierarchical","demonstrate","sometimes","interventions","confounders","expensive","controlled","composition","nonparametrically","classification","regression","regularized","introduced","increased","expectations","proportional","necessarily","generated","evaluation","conditions","uncertain","inference","reasoning","restricted","solutions","consistent","deteriorates","identified","generally","prospector","calculations","surprisingly","classifier","supporting","measurement","compressive","diversity","hyperspectral","compressed","isolating","processing","suitability","reconstruct","correspondence","consecutive","conventional","computing","navigation","substantial","extracted","complexity","developed","environment","autonomous","considerable","essential","operational","computational","estimated","keypoints","laboratory","correspond","simplifying","axiomatic","uncertainty","naturally","replacing","informational","qualitative","possibility","attitudes","unification","represented","optimistic","described","comparison","pessimistic","appropriate","smoothness","efficiency","resulting","optimization","accelerated","expressed","projected","simulation","regularization","collected","techniques","increasingly","challenge","applications","belonging","determine","successful","understanding","additionally","characteristics","clustering","unlabeled","discovering","visualizations","accurately","diagnosis","similarity","complementarity","regressors","decomposes","explanation","definition","recognition","researchers","generalized","theoretical","ambiguity","answering","achieving","improvement","approximately","difference","empirically","extension ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nonparametrically
# 	triangular
# 	invertibility
# 	economical
# 	thermostat
# 	thermostats
# 	lindenstrauss
# 	textitnot
# 	reseeding
# 	dominates
# 	integrands
# 	econometrics
# 	underscore
# 	robustification
# 	stragglers
# 	straggler
# 	purchasing
# 	timelines
# 	warranted
# 	nonparanormal
# Some words which never appear in Statistics papers:
# 	prospector
# 	isolating
# 	keypoints
# 	informational
# 	automaton
# 	reservoir
# 	declarative
# 	annotator
# 	objectscene
# 	monocular
# 	occlusions
# 	irregularities
# 	arrhythmia
# 	preoperative
# 	ultrasound
# 	deductive
# 	superpixel
# 	predominately
# 	milestone
# 	untrimmed

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.059881888559102e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.755
